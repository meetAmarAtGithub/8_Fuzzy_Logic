# %% [markdown]
# <a href="https://colab.research.google.com/github/meetAmarAtGithub/8_Fuzzy_Logic/blob/main/Day2/3_RFCM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data(iris)

# %%
x <- iris

# %%
x <- iris[,-5]

# %%
x
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1   5.1          3.5         1.4          0.2
# 2   4.9          3.0         1.4          0.2
# 3   4.7          3.2         1.3          0.2
# 4   4.6          3.1         1.5          0.2
# 5   5.0          3.6         1.4          0.2
# 6   5.4          3.9         1.7          0.4
# 7   4.6          3.4         1.4          0.3
# 8   5.0          3.4         1.5          0.2
# 9   4.4          2.9         1.4          0.2
# 10  4.9          3.1         1.5          0.1
# 11  5.4          3.7         1.5          0.2
# 12  4.8          3.4         1.6          0.2
# 13  4.8          3.0         1.4          0.1
# 14  4.3          3.0         1.1          0.1
# 15  5.8          4.0         1.2          0.2
# 16  5.7          4.4         1.5          0.4
# 17  5.4          3.9         1.3          0.4
# 18  5.1          3.5         1.4          0.3
# 19  5.7          3.8         1.7          0.3
# ...

# %%
hist(x$Sepal.Length)
# Out:
# Plot with title “Histogram of x$Sepal.Length”

# %%
hist(x$Sepal.Width)
# Out:
# Plot with title “Histogram of x$Sepal.Width”

# %%
hist(x$Petal.Width)
# Out:
# Plot with title “Histogram of x$Petal.Width”

# %%
hist(x$Petal.Length)
# Out:
# Plot with title “Histogram of x$Petal.Length”

# %%
pairs(x, col=iris[,5])
# Out:
# plot without title

# %%
install.packages("e1071")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘proxy’

# %%
library(e1071)

# %%
model42 <- cmeans(x, 2, iter.max = 100, verbose = TRUE,
       dist = "euclidean", method = "cmeans", m = 2,
       rate.par = NULL, weights = 1, control = list())
# Out:
# Iteration:   1, Error:  0.8729407007
# Iteration:   2, Error:  0.8600615452
# Iteration:   3, Error:  0.8593549705
# Iteration:   4, Error:  0.8593035882
# Iteration:   5, Error:  0.8592996475
# Iteration:   6, Error:  0.8592993423
# Iteration:   7, Error:  0.8592993186
# Iteration:   8 converged, Error:  0.8592993167

# %%
model43 <- cmeans(x, 3, iter.max = 100, verbose = TRUE,
       dist = "euclidean", method = "cmeans", m = 2,
       rate.par = NULL, weights = 1, control = list())
# Out:
# Iteration:   1, Error:  1.3473102603
# Iteration:   2, Error:  0.8626377270
# Iteration:   3, Error:  0.6340905072
# Iteration:   4, Error:  0.4873234910
# Iteration:   5, Error:  0.4382936727
# Iteration:   6, Error:  0.4195594702
# Iteration:   7, Error:  0.4108975794
# Iteration:   8, Error:  0.4067954172
# Iteration:   9, Error:  0.4048914129
# Iteration:  10, Error:  0.4040326139
# Iteration:  11, Error:  0.4036547916
# Iteration:  12, Error:  0.4034916248
# Iteration:  13, Error:  0.4034220580
# Iteration:  14, Error:  0.4033926512
# Iteration:  15, Error:  0.4033802904
# Iteration:  16, Error:  0.4033751137
# Iteration:  17, Error:  0.4033729508
# Iteration:  18, Error:  0.4033720485
# Iteration:  19, Error:  0.4033716725
# Iteration:  20, Error:  0.4033715159
# Iteration:  21, Error:  0.4033714507
# Iteration:  22, Error:  0.4033714235
# Iteration:  23, Error:  0.4033714122
# Iteration:  24 converged, Error:  0.4033714075

# %%
model44 <- cmeans(x, 4, iter.max = 100, verbose = TRUE,
       dist = "euclidean", method = "cmeans", m = 2,
       rate.par = NULL, weights = 1, control = list())
# Out:
# Iteration:   1, Error:  0.6360183036
# Iteration:   2, Error:  0.5869052043
# Iteration:   3, Error:  0.4664652104
# Iteration:   4, Error:  0.3896707125
# Iteration:   5, Error:  0.3584569150
# Iteration:   6, Error:  0.3303378192
# Iteration:   7, Error:  0.3099789805
# Iteration:   8, Error:  0.2954011518
# Iteration:   9, Error:  0.2864045908
# Iteration:  10, Error:  0.2817969477
# Iteration:  11, Error:  0.2796273438
# Iteration:  12, Error:  0.2785925007
# Iteration:  13, Error:  0.2780725827
# Out:
#              Sepal.Length Sepal.Width Petal.Length Petal.Width
# Sepal.Length  1.0000000   -0.1175698   0.8717538    0.8179411
# Sepal.Width  -0.1175698    1.0000000  -0.4284401   -0.3661259
# Petal.Length  0.8717538   -0.4284401   1.0000000    0.9628654
# Petal.Width   0.8179411   -0.3661259   0.9628654    1.0000000

# %%
x2 <- x[, 2:3]

# %%
x2
# Out:
#     Sepal.Width Petal.Length
# 1   3.5         1.4
# 2   3.0         1.4
# 3   3.2         1.3
# 4   3.1         1.5
# 5   3.6         1.4
# 6   3.9         1.7
# 7   3.4         1.4
# 8   3.4         1.5
# 9   2.9         1.4
# 10  3.1         1.5
# 11  3.7         1.5
# 12  3.4         1.6
# 13  3.0         1.4
# 14  3.0         1.1
# 15  4.0         1.2
# 16  4.4         1.5
# 17  3.9         1.3
# 18  3.5         1.4
# 19  3.8         1.7
# 20  3.8         1.5
# 21  3.4         1.7
# 22  3.7         1.5
# 23  3.6         1.0
# 24  3.3         1.7
# 25  3.4         1.9
# 26  3.0         1.6
# 27  3.4         1.6
# 28  3.5         1.5
# 29  3.4         1.4
# 30  3.2         1.6
# ⋮   ⋮           ⋮
# 121 3.2         5.7
# 122 2.8         4.9
# 123 2.8         6.7
# 124 2.7         4.9
# 125 3.3         5.7
# 126 3.2         6.0
# 127 2.8         4.8
# 128 3.0         4.9
# 129 2.8         5.6
# 130 3.0         5.8
# 131 2.8         6.1
# 132 3.8         6.4
# 133 2.8         5.6
# ...

# %%
model22 <- cmeans(x2, 2, iter.max = 100, verbose = TRUE,
       dist = "euclidean", method = "cmeans", m = 2,
       rate.par = NULL, weights = 1, control = list())
# Out:
# Iteration:   1, Error:  0.4972818417
# Iteration:   2, Error:  0.4968707211
# Iteration:   3, Error:  0.4968587939
# Iteration:   4, Error:  0.4968582116
# Iteration:   5, Error:  0.4968581827
# Iteration:   6 converged, Error:  0.4968581812

# %%
model23 <- cmeans(x2, 3, iter.max = 100, verbose = TRUE,
       dist = "euclidean", method = "cmeans", m = 2,
       rate.par = NULL, weights = 1, control = list())
# Out:
# Iteration:   1, Error:  0.8029381799
# Iteration:   2, Error:  0.2587332747
# Iteration:   3, Error:  0.2129270840
# Iteration:   4, Error:  0.2125524682
# Iteration:   5, Error:  0.2125100323
# Iteration:   6, Error:  0.2124961106
# Iteration:   7, Error:  0.2124904502
# Iteration:   8, Error:  0.2124880478
# Iteration:   9, Error:  0.2124870186
# Iteration:  10, Error:  0.2124865765
# Iteration:  11, Error:  0.2124863864
# Iteration:  12, Error:  0.2124863046
# Iteration:  13, Error:  0.2124862694
# Iteration:  14, Error:  0.2124862542
# Iteration:  15, Error:  0.2124862477
# Iteration:  16 converged, Error:  0.2124862449

# %%
model24 <- cmeans(x2, 4, iter.max = 100, verbose = TRUE,
       dist = "euclidean", method = "cmeans", m = 2,
       rate.par = NULL, weights = 1, control = list())
# Out:
# Iteration:   1, Error:  0.2006755924
# Iteration:   2, Error:  0.1761344639
# Iteration:   3, Error:  0.1624362319
# Iteration:   4, Error:  0.1582140445
# Iteration:   5, Error:  0.1536160729
# Iteration:   6, Error:  0.1468739287
# Iteration:   7, Error:  0.1422941028
# Iteration:   8, Error:  0.1406303153
# Iteration:   9, Error:  0.1401609218
# Iteration:  10, Error:  0.1400275508
# Iteration:  11, Error:  0.1399840859
# Iteration:  12, Error:  0.1399671744
# Iteration:  13, Error:  0.1399595090
# Iteration:  14, Error:  0.1399556705
# Iteration:  15, Error:  0.1399536425
# Iteration:  16, Error:  0.1399525433
# Iteration:  17, Error:  0.1399519407
# Iteration:  18, Error:  0.1399516087
#   [1,] 0.0004475478 0.0556638703 0.0011981759 0.8969857959 0.0449744203
#   [2,] 0.0001732790 0.0043752358 0.0005004579 0.0173657165 0.9772967578
#   [3,] 0.0012230263 0.0496281586 0.0033479408 0.2832715621 0.6605301723
#   [4,] 0.0003488884 0.0109036539 0.0010263361 0.0576296113 0.9295045316
#   [5,] 0.0010842812 0.2294612887 0.0028477065 0.6915590278 0.0732889544
#   [6,] 0.0014579663 0.8563746714 0.0038148506 0.1025073146 0.0334532710
#   [7,] 0.0003713496 0.0300371420 0.0010122568 0.9065610963 0.0614090695
#   [8,] 0.0001014223 0.0083425400 0.0002839765 0.9755713121 0.0155323369
# ...

# %%
model26$centers
# Out:
#   Sepal.Width Petal.Length
# 1 3.086829    5.886387
# 2 3.884242    1.524743
# 3 2.639694    4.015686
# 4 3.440786    1.481372
# 5 3.051578    1.430163
# 6 2.900112    4.875833

# %%
model26$size
# Out:
# [1] 30 13 29 20 17 41

# %%
model26$cluster
# Out:
#   [1] 4 5 5 5 4 2 4 4 5 5 2 4 5 5 2 2 2 4 2 2 4 2 4 4 4 5 4 4 4 5 5 4 2 2 5 5 4
#  [38] 4 5 4 4 5 5 4 2 5 2 5 2 4 6 6 6 3 6 6 6 3 6 3 3 3 3 6 3 6 6 3 3 3 6 3 6 6
#  [75] 3 6 6 6 6 3 3 3 3 6 6 6 6 3 3 3 3 6 3 3 3 3 3 3 3 3 1 6 1 1 1 1 3 1 1 1 6
# [112] 6 1 6 6 6 1 1 1 6 1 6 1 6 1 1 6 6 1 1 1 1 1 6 1 1 1 1 6 1 1 6 6 1 1 6 6 6
# [149] 1 6

# %%
x$cluster <- model26$cluster

# %%
head(x)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width cluster
# 1 5.1          3.5         1.4          0.2         4
# 2 4.9          3.0         1.4          0.2         5
# 3 4.7          3.2         1.3          0.2         5
# 4 4.6          3.1         1.5          0.2         5
# 5 5.0          3.6         1.4          0.2         4
# 6 5.4          3.9         1.7          0.4         2

# %%
xo <- iris

# %%
xo$cluster <- model26$cluster

# %%
sample(xo)
# Out:
#     Petal.Width Sepal.Length Sepal.Width Petal.Length Species   cluster
# 1   0.2         5.1          3.5         1.4          setosa    4
# 2   0.2         4.9          3.0         1.4          setosa    5
# 3   0.2         4.7          3.2         1.3          setosa    5
# 4   0.2         4.6          3.1         1.5          setosa    5
# 5   0.2         5.0          3.6         1.4          setosa    4
# 6   0.4         5.4          3.9         1.7          setosa    2
# 7   0.3         4.6          3.4         1.4          setosa    4
# 8   0.2         5.0          3.4         1.5          setosa    4
# 9   0.2         4.4          2.9         1.4          setosa    5
# 10  0.1         4.9          3.1         1.5          setosa    5
# 11  0.2         5.4          3.7         1.5          setosa    2
# 12  0.2         4.8          3.4         1.6          setosa    4
# 13  0.1         4.8          3.0         1.4          setosa    5
# ...

# %%
table(xo$cluster, xo$Species)
# Out:
#
#     setosa versicolor virginica
#   1      0          0        30
#   2     13          0         0
#   3      0         28         1
#   4     20          0         0
#   5     17          0         0
#   6      0         22        19
